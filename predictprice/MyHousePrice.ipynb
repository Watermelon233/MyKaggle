# %%
#invite people for the Kaggle party
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('train.csv')
data.shape
# Out:
# (1460, 81)

# %%
missingdata = data.isnull().sum()

# %%
dropna = data.drop(missingdata[missingdata>50].index,1)

# %%
dropna=dropna.dropna()

# %%
dropna.shape
# Out:
# (1412, 70)

# %%
corrmat=dropna.corr()
f, ax = plt.subplots(figsize=(15, 10))
sns.heatmap(corrmat, vmax=.8, square=True,cmap='rainbow');

# %%
corrsort = abs(corrmat['SalePrice'])
corrsort[corrsort<0.1]
corrsort.sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.786765
# GrLivArea        0.711080
# GarageCars       0.641825
# GarageArea       0.621095
# 1stFlrSF         0.614753
# TotalBsmtSF      0.611084
# FullBath         0.575604
# TotRmsAbvGrd     0.545540
# YearBuilt        0.518736
# YearRemodAdd     0.500266
# MasVnrArea       0.474525
# Fireplaces       0.462937
# BsmtFinSF1       0.368849
# 2ndFlrSF         0.317948
# WoodDeckSF       0.317361
# OpenPorchSF      0.304972
# HalfBath         0.270145
# LotArea          0.264803
# BsmtFullBath     0.208756
# BsmtUnfSF        0.188959
# BedroomAbvGr     0.170174
# EnclosedPorch    0.134342
# ScreenPorch      0.108208
# KitchenAbvGr     0.105743
# OverallCond      0.093567
# PoolArea         0.092776
# MSSubClass       0.082281
# 3SsnPorch        0.047040
# MoSold           0.041754
# LowQualFinSF     0.028428
# Id               0.024651
# YrSold           0.023361
# BsmtHalfBath     0.022093
# BsmtFinSF2       0.020196
# MiscVal          0.013287
# Name: SalePrice, dtype: float64

# %%
fdata=dropna.drop(corrsort[corrsort<0.1].index,axis=1)

# %%
fdata[:10]
# Out:
#   MSZoning  LotArea Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL     8450   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL     9600   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL    11250   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL     9550   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL    14260   Pave      IR1         Lvl    AllPub       FR2       Gtl
# 5       RL    14115   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 6       RL    10084   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 7       RL    10382   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 8       RM     6120   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 9       RL     7420   Pave      Reg         Lvl    AllPub    Corner       Gtl
#
#   Neighborhood Condition1    ...    GarageCars GarageArea PavedDrive  \
# 0      CollgCr       Norm    ...             2        548          Y
# 1      Veenker      Feedr    ...             2        460          Y
# 2      CollgCr       Norm    ...             2        608          Y
# 3      Crawfor       Norm    ...             3        642          Y
# 4      NoRidge       Norm    ...             3        836          Y
# 5      Mitchel       Norm    ...             2        480          Y
# 6      Somerst       Norm    ...             2        636          Y
# 7       NWAmes       PosN    ...             2        484          Y
# 8      OldTown     Artery    ...             2        468          Y
# 9      BrkSide     Artery    ...             1        205          Y
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch ScreenPorch SaleType SaleCondition  \
# 0           0           61              0           0       WD        Normal
# 1         298            0              0           0       WD        Normal
# 2           0           42              0           0       WD        Normal
# 3           0           35            272           0       WD       Abnorml
# 4         192           84              0           0       WD        Normal
# 5          40           30              0           0       WD        Normal
# 6         255           57              0           0       WD        Normal
# 7         235          204            228           0       WD        Normal
# 8          90            0            205           0       WD       Abnorml
# 9           0            4              0           0       WD        Normal
#
#   SalePrice
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# 5    143000
# 6    307000
# 7    200000
# 8    129900
# 9    118000
#
# [10 rows x 59 columns]

# %%
df_train = pd.get_dummies(fdata)

# %%
fdata.plot.scatter(x='OverallQual',y='SalePrice')

# %%
sns.distplot(fdata['SalePrice'], fit=norm);
fig = plt.figure()
res = stats.probplot(fdata['SalePrice'], plot=plt)

# %%
fdata['SalePrice'] = np.log(fdata['SalePrice'])

# %%
sns.distplot(df_train['SalePrice'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_train['SalePrice'], plot=plt)

# %%
sns.distplot(fdata['GrLivArea'], fit=norm);
fig = plt.figure()
res = stats.probplot(fdata['GrLivArea'], plot=plt)

# %%
fdata['GrLivArea']= np.log(fdata['GrLivArea'])

# %%
sns.distplot(fdata['GrLivArea'], fit=norm);
fig = plt.figure()
res = stats.probplot(fdata['GrLivArea'], plot=plt)

# %%
sns.distplot(fdata['1stFlrSF'], fit=norm);
fig = plt.figure()
res = stats.probplot(fdata['1stFlrSF'], plot=plt)

# %%
fdata['1stFlrSF']= np.log(fdata['1stFlrSF'])

# %%
sns.distplot(fdata['YearBuilt'], fit=norm);
fig = plt.figure()
res = stats.probplot(fdata['YearBuilt'], plot=plt)

# %%
X_train = fdata.drop('SalePrice',axis=1)
X_train.shape
# Out:
# (1412, 58)

# %%
Y_train = fdata['SalePrice']

# %%
from sklearn import linear_model

# %%
reg= linear_model.LinearRegression()

# %%
X_train = pd.get_dummies(fdata.drop('SalePrice',axis=1))
X_train.shape
# Out:
# (1412, 235)

# %%
reg.fit(X=X_train,y=Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
reg.coef_
# Out:
# (235,)

# %%
Y_predict = X_train.dot(reg.coef_)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mean_squared_error(Y_predict,Y_train)
# Out:
# 9.5176414167848318

# %%
X_test = pd.read_csv('test.csv',index_col='Id')
X_test[:10]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
# 1466          60       RL         75.0    10000   Pave   NaN      IR1
# 1467          20       RL          NaN     7980   Pave   NaN      IR1
# 1468          60       RL         63.0     8402   Pave   NaN      IR1
# 1469          20       RL         85.0    10176   Pave   NaN      Reg
# 1470          20       RL         70.0     8400   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig      ...       ScreenPorch PoolArea  \
# Id                                        ...
# 1461         Lvl    AllPub    Inside      ...               120        0
# 1462         Lvl    AllPub    Corner      ...                 0        0
# 1463         Lvl    AllPub    Inside      ...                 0        0
# 1464         Lvl    AllPub    Inside      ...                 0        0
# 1465         HLS    AllPub    Inside      ...               144        0
# 1466         Lvl    AllPub    Corner      ...                 0        0
# 1467         Lvl    AllPub    Inside      ...                 0        0
# 1468         Lvl    AllPub    Inside      ...                 0        0
# 1469         Lvl    AllPub    Inside      ...                 0        0
# 1470         Lvl    AllPub    Corner      ...                 0        0
#
#      PoolQC  Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  \
# Id
# 1461    NaN  MnPrv         NaN       0       6    2010        WD
# 1462    NaN    NaN        Gar2   12500       6    2010        WD
# 1463    NaN  MnPrv         NaN       0       3    2010        WD
# 1464    NaN    NaN         NaN       0       6    2010        WD
# 1465    NaN    NaN         NaN       0       1    2010        WD
# 1466    NaN    NaN         NaN       0       4    2010        WD
# 1467    NaN  GdPrv        Shed     500       3    2010        WD
# 1468    NaN    NaN         NaN       0       5    2010        WD
# 1469    NaN    NaN         NaN       0       2    2010        WD
# 1470    NaN  MnPrv         NaN       0       4    2010        WD
#
#       SaleCondition
# Id
# 1461         Normal
# 1462         Normal
# 1463         Normal
# 1464         Normal
# 1465         Normal
# 1466         Normal
# 1467         Normal
# 1468         Normal
# 1469         Normal
# 1470         Normal
#
# [10 rows x 79 columns]

# %%
full_data = pd.concat([fdata,X_test],axis=0)
full_data.shape
# Out:
# (2871, 80)

# %%
full_data = full_data[fdata.drop('SalePrice',axis=1).columns]
full_data.shape
# Out:
# (2871, 58)

# %%
full_test = pd.get_dummies(full_data)
full_test = full_test[X_train.columns]
full_test.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-0d8515f87617> in <module>()
#       1 full_test = pd.get_dummies(full_data)
# ----> 2 full_test = full_test[X_train.columns]
#       3 full_test.shape
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',\n       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',\n       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',\n       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',\n       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',\n       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',\n       'Functional', 'PavedDrive', 'SaleType', 'SaleCondition'],\n      dtype='object') not in index"

# %%
Y_test = reg.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-c2e871b607f2> in <module>()
# ----> 1 Y_test = reg.predict(X_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     254             Returns predicted values.
#     255         """
# --> 256         return self._decision_function(X)
#     257
#     258     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     239         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     240         return safe_sparse_dot(X, self.coef_.T,
# --> 241                                dense_output=True) + self.intercept_
#     242
#     243     def predict(self, X):
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     138         return ret
#     139     else:
# --> 140         return np.dot(a, b)
#     141
#     142
#
# ValueError: shapes (1459,224) and (235,) not aligned: 224 (dim 1) != 235 (dim 0)

# %%
X_test.shape
# Out:
# (1459, 69)

# %% [markdown]
# # 从头开始
# 使用sklearn

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LassoCV
from sklearn import preprocessing
# %matplotlib inline

# %%
lasso = LassoCV()

# %%
data = pd.read_csv('train.csv',index_col='Id')
X_Ptest = pd.read_csv('test.csv',index_col='Id')
m,n = data.shape

fulldata =pd.concat([data.drop('SalePrice',1),X_Ptest])
missingdata = fulldata.isnull().sum()
dropna = fulldata.drop(missingdata[missingdata>50].index,1)
dropna.shape
# Out:
# (2919, 63)

# %%
dropna = dropna.fillna(0)
ready_data = pd.get_dummies(dropna)
ready_data.shape
# Out:
# (2919, 234)

# %%
X_train = ready_data[:1460]

Pdata = ready_data[1460:]

# %%
Y_train = data['SalePrice']

# %%
X_strain = preprocessing.MinMaxScaler(X_train)
X_strain
# Out:
# MinMaxScaler(copy=True,
#        feature_range=      MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id
# 1             60     8450            7            5       2003          2003
# 2             20     9600            6        ...1460                     0                     1                      0
#
# [1460 rows x 234 columns])

# %%
lasso.fit(X_strain,Y_train)
result = lasso.predict(Pdata)

# %%
result.tofile('result.csv')

# %%
sub = pd.Series(result,Pdata.index,)

# %%
sub.to_csv('sub.csv')
